# %% [markdown]
# ##### IMPORTS AND FUNCTION DEFINITIONS

# %%
import pandas as pd
from pyannote.metrics.diarization import DiarizationErrorRate
from pyannote.core import Segment, Timeline, Annotation
from itertools import product
import os

# Use below only to analyze single speaker diarization
# TARGET_MODEL_SPEAKER = 'speaker_1'
# TARGET_GOLD_SPEAKER = 'SPEAKER_00'

def convert_model_csv_to_rrtm(model_root_folder, csv_filename):
    """
    Convert the diarization model's CSV output to RTTM format for scoring with pyannote diarization error metrics.
    
    Args:
        model_root_folder (str): The root folder where the model's CSV output is located.
        csv_filename (str): The name of the CSV file to convert.
    Returns:
        None: Writes the RTTM file to the same directory as the CSV file in the diarization model's output folder.
    """

    # Handle P5-S8 to trim upto where gold label exists.
    P5_S8_LIMIT = 1719.725

    with open(os.path.join(model_root_folder, csv_filename[:-4]+".rttm"), 'w') as rttm_file:
        df = pd.read_csv(f"{model_root_folder}/{csv_filename}")
        for _, row in df.iterrows():
            # if(row['speaker'] == TARGET_MODEL_SPEAKER):
                begin = float(row['speech_start'])
                end = float(row['speech_end'])
                speaker = row['speaker']

                # Special handling for p5-s8
                if "p5-s8" in csv_filename:
                    # Ignore segments that start after gold labels end
                    if begin >= P5_S8_LIMIT:
                         continue
                    # Truncate segments that cross the boundary
                    end = min(end, P5_S8_LIMIT)

                # RTTM format: SPEAKER <file> <channel> <begin> <duration> <conf> <speech_type> <speaker_type> <speaker_name>
                duration = end - begin
                if duration <= 0:
                     continue
                rttm_line = f"SPEAKER {begin:.3f} {duration:.3f} <NA> <NA> <NA> {speaker}\n"
                
                rttm_file.write(rttm_line)

def convert_gold_label_txt_to_rrtm(gold_label_root_folder, txt_filename):
    """
    Convert the gold label diarization annotations from a TXT file (from ELAN) to RTTM format for scoring with pyannote diarization error metrics.
    
    Args:
        gold_label_root_folder (str): The root folder where the gold label TXT file is located.
        txt_filename (str): The name of the TXT file to convert.
    Returns:
        None: Writes the RTTM file to the same directory as the TXT file in the gold label annotations folder.
    """

    df = pd.read_csv(os.path.join(gold_label_root_folder, txt_filename), sep='\t')
    # Create RTTM output
    with open(os.path.join(gold_label_root_folder, txt_filename[:-4]+".rttm"), 'w') as rttm_file:
        for idx, row in df.iterrows():
            # if(row['speaker'] == TARGET_GOLD_SPEAKER):
                begin = float(row['speech_start'])
                end = float(row['speech_end'])
                speaker = row['speaker']
                # RTTM format: SPEAKER <file> <channel> <begin> <duration> <conf> <speech_type> <speaker_type> <speaker_name>
                duration = end - begin
                rttm_line = f"SPEAKER {begin:.3f} {duration:.3f} <NA> <NA> <NA> {speaker}\n"
                rttm_file.write(rttm_line)

def load_rttm_to_annotation(path):
    """Load an RTTM file and convert it to a pyannote.core.Annotation object.
    Args:
        path (str): Path to the RTTM file.
    Returns:
        pyannote.core.Annotation: The loaded annotation."""
    ann = Annotation()
    with open(path, 'r') as fh:
        for line in fh:
            line = line.strip()
            if not line:
                continue
            parts = line.split()
            if parts[0] != 'SPEAKER':
                continue
            # handle both custom and standard RTTM token positions
            try:
                start = float(parts[1])
                dur = float(parts[2])
                speaker = parts[-1]
            except Exception:
                start = float(parts[3])
                dur = float(parts[4])
                speaker = parts[-1]
            ann[Segment(start, start + dur)] = speaker
    return ann

def der_component_conversion(der_dict):
    """Convert the DER components from a dictionary to a more human-readable format.
    Args:
        der_dict (dict): The dictionary containing DER components.
    Returns:
        dict: A dictionary with human-readable DER components."""
    return {
        'missed_speech_percent': f"{100*der_dict['missed detection']/der_dict['total']:.2f}",
        'false_alarm_percent': f"{100*der_dict['false alarm']/der_dict['total']:.2f}",
        'confusion_percent': f"{100*der_dict['confusion']/der_dict['total']:.2f}",
        "correct_percent": f"{100*der_dict['correct']/der_dict['total']:.2f}",
        "der": f"{100*der_dict['diarization error rate']:.2f}"
    }

# %% [markdown]
# ##### SPECIFY FILE_ID, VARIANT_TYPES AND RESULT FORMAT

# %%
ids = [
    "p5-s8",
    "p5-s10",
    "p7-s8",
    "p7-s16",
    "p9-s3-1",
    "p9-s9",
    "p11-s4",
    "p11-s11",
    "p12-s3",
    "p12-s6",
    "p17-s2",
    "p17-s6",
    "p18-s15",
    "p18-s17",
]

AUDIO_TYPES = [
    "raw_audios",
    "denoised_audios",
]

SPEAKER_MODES = [
    "fixed_num-speakers",
    "auto_num-speakers"
]

OVERLAP_MODES = [
    "overlap",
    "no_overlap",
]

# Cartesian product of all possible combinations
all_configs = list(product(
    AUDIO_TYPES,
    SPEAKER_MODES,
    OVERLAP_MODES
))

results = {
    "Audio Type": [],
    "Speaker Mode": [],
    "Overlap Mode": [],
    "video_id": [], # Corresponds to the file id in other parts of the script
    "DER": [],
    "False Alarm %": [],
    "Missed Speech %": [],
    "Confusion %": [],
    "Correct %": []
}

# %% [markdown]
# ##### SPECIFY MAPPING FOR CSV FILES (IF CREATED)

# %%
#Mapping for the abbreviations, when creating the CSV file names

AUDIO_MAP = {
    "raw_audios": "RAW",
    "denoised_audios": "DENOISED"
}

SPEAKER_MAP = {
    "fixed_num-speakers": "FIXED",
    "auto_num-speakers": "AUTO"
}

OVERLAP_MAP = {
    "overlap": "OVERLAP",
    "no_overlap": "NO_OVERLAP"
}

# %% [markdown]
# ##### GENERATE ALL GOLD LABEL RTTMS AT ONCE

# %%
# Path to Reference (Gold Labels) folder
ref_root = "gold_label_diarization_annotations"

# print("Generating gold RTTMs...")

for file_id in ids:

    ref_file_name = f"{file_id}_gold_labels"

    convert_gold_label_txt_to_rrtm(
        ref_root,
        ref_file_name + ".txt"
    )

# print("Done.")

# %% [markdown]
# ##### LOOP THROUGH COMBINATIONS

# %%
os.makedirs("der_results", exist_ok=True)

# Path to Reference (Gold Labels) folder
ref_root = "gold_label_diarization_annotations"


summary_results = []

# Loops thorugh all variants
for (
    audio_type,
    speaker_mode,
    overlap_mode
) in all_configs:
    
    # Current configuation's result format to store in CSV output
    config_results = {
        "video_id": [],
        "DER": [],
        "False Alarm %": [],
        "Missed Speech %": [],
        "Confusion %": [],
        "Correct %": []
    }

    # Path to hypothetical (model) diarization outputs
    hyp_root = os.path.join(
        "pyannote_outputs", 
        audio_type,
        speaker_mode,
        "csv"
    )

    # Loop through all the audio samples 
    for file_id in ids:
        
        # Path to the sample's Gold Label (Reference) file
        ref_file_name = f"{file_id}_gold_labels"
        
        # Path to the sample's model output (Hypothesis) file
        if audio_type == "denoised_audios":
            hyp_file_name = f"{file_id}_denoised"
        else:
            hyp_file_name = file_id

        try:

            convert_model_csv_to_rrtm(
                hyp_root,
                hyp_file_name + ".csv"
            )

            ref = load_rttm_to_annotation(
                os.path.join(
                    ref_root,
                    ref_file_name + ".rttm"
                )
            )

            hyp = load_rttm_to_annotation(
                os.path.join(
                    hyp_root,
                    hyp_file_name + ".rttm"
                )
            )

            # Decide which overlap mode
            skip_overlap = (overlap_mode == "no_overlap")

            metric = DiarizationErrorRate(
                collar=0.25,
                skip_overlap=skip_overlap
            )

            der = der_component_conversion(
                metric(ref, hyp, detailed=True)
            )

            # Append the current results to the main RESULTS dataframe
            results["video_id"].append(file_id)

            results["Audio Type"].append(audio_type)
            results["Speaker Mode"].append(speaker_mode)
            results["Overlap Mode"].append(overlap_mode)

            results["DER"].append(float(der["der"]))
            results["False Alarm %"].append(float(der["false_alarm_percent"]))
            results["Missed Speech %"].append(float(der["missed_speech_percent"]))
            results["Confusion %"].append(float(der["confusion_percent"]))
            results["Correct %"].append(float(der["correct_percent"]))


            # Append the current results to a temporary CONFIG_RESULTS dataframe to store into a seperate CSV file
            config_results["video_id"].append(file_id)
            config_results["DER"].append(float(der["der"]))
            config_results["False Alarm %"].append(float(der["false_alarm_percent"]))
            config_results["Missed Speech %"].append(float(der["missed_speech_percent"]))
            config_results["Confusion %"].append(float(der["confusion_percent"]))
            config_results["Correct %"].append(float(der["correct_percent"]))

        except Exception as e:

            print(
                f"Failed: {audio_type},{speaker_mode},{overlap_mode} | {file_id}"
            )

            print(e)

    config_df = pd.DataFrame(config_results)

    # Configure the name of the csv file for current configuration/ model combination 
    csv_name = (
        f"-audio_{AUDIO_MAP[audio_type]}"
        f"-speaker_{SPEAKER_MAP[speaker_mode]}"
        f"-overlap_{OVERLAP_MAP[overlap_mode]}"
        f"-params_OLD.csv"
    )
    
    # Generate Summary for the model config
    summary_row = {
    "CSV Name": csv_name.replace(".csv", ""),

    "DER Mean": config_df["DER"].mean(),
    "DER Median": config_df["DER"].median(),
    "DER Std": config_df["DER"].std(),

    "FA Mean": config_df["False Alarm %"].mean(),
    "FA Median": config_df["False Alarm %"].median(),
    "FA Std": config_df["False Alarm %"].std(),

    "Missed Mean": config_df["Missed Speech %"].mean(),
    "Missed Median": config_df["Missed Speech %"].median(),
    "Missed Std": config_df["Missed Speech %"].std(),

    "Confusion Mean": config_df["Confusion %"].mean(),
    "Confusion Median": config_df["Confusion %"].median(),
    "Confusion Std": config_df["Confusion %"].std(),

    "Correct Mean": config_df["Correct %"].mean(),
    "Correct Median": config_df["Correct %"].median(),
    "Correct Std": config_df["Correct %"].std(),
    }
    
    summary_results.append(summary_row)
    
    # Craete a csv
    config_df.to_csv(
        os.path.join("der_results", csv_name),
        index=False
    )

    print(f"Saved: {csv_name}")


summary_df = pd.DataFrame(summary_results)

summary_df.to_csv(
    "der_results/summary.csv",
    index=False
)

summary_df
# Out:
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# Saved: -audio_RAW-speaker_FIXED-overlap_OVERLAP-params_OLD.csv
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# /home/interactionlab/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# Saved: -audio_RAW-speaker_FIXED-overlap_NO_OVERLAP-params_OLD.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 76
#      68 skip_overlap = (overlap_mode == "no_overlap")
#      70 metric = DiarizationErrorRate(
#      71     collar=0.25,
#      72     skip_overlap=skip_overlap
#      73 )
#      75 der = der_component_conversion(
# ---> 76     metric(ref, hyp, detailed=True)
#      77 )
#      79 # Append the current results to the main RESULTS dataframe
#      80 results["video_id"].append(file_id)
#
# File ~/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/base.py:114, in BaseMetric.__call__(self, reference, hypothesis, detailed, uri, **kwargs)
#      90 """Compute metric value and accumulate components
#      91
#      92 Parameters
#    (...)
#     110     `components` updated with metric value
#     111 """
#     113 # compute metric components
# --> 114 components = self.compute_components(reference, hypothesis, **kwargs)
#     116 # compute rate based on components
#     117 components[self.metric_name_] = self.compute_metric(components)
#
# File ~/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/diarization.py:174, in DiarizationErrorRate.compute_components(self, reference, hypothesis, uem, **kwargs)
#     170 # compute identification error rate based on mapped hypothesis
#     171 # NOTE that collar is set to 0.0 because 'uemify' has already
#     172 # been applied (same reason for setting skip_overlap to False)
#     173 mapped = hypothesis.rename_labels(mapping=mapping)
# --> 174 return super(DiarizationErrorRate, self).compute_components(
#     175     reference, mapped, uem=uem, collar=0.0, skip_overlap=False, **kwargs
#     176 )
#
# File ~/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/identification.py:133, in IdentificationErrorRate.compute_components(self, reference, hypothesis, uem, collar, skip_overlap, **kwargs)
#     130 if skip_overlap is None:
#     131     skip_overlap = self.skip_overlap
# --> 133 R, H, common_timeline = self.uemify(
#     134     reference, hypothesis, uem=uem,
#     135     collar=collar, skip_overlap=skip_overlap,
#     136     returns_timeline=True)
#     138 # loop on all segments
#     139 for segment in common_timeline:
#     140     # segment duration
#
# File ~/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/metrics/utils.py:210, in UEMSupportMixin.uemify(self, reference, hypothesis, uem, collar, skip_overlap, returns_uem, returns_timeline)
#     208 # extrude regions outside of uem
#     209 reference = reference.crop(uem, mode='intersection')
# --> 210 hypothesis = hypothesis.crop(uem, mode='intersection')
#     212 # project reference and hypothesis on common timeline
#     213 if returns_timeline:
#
# File ~/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/core/annotation.py:557, in Annotation.crop(self, support, mode)
#     553     return cropped
#     555 elif mode == "intersection":
# --> 557     for segment, other_segment in self.get_timeline(copy=False).co_iter(
#     558         support
#     559     ):
#     561         intersection = segment & other_segment
#     562         for track, label in self._tracks[segment].items():
#
# File ~/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/core/timeline.py:407, in Timeline.co_iter(self, other)
#     405 temp = Segment(start=segment.end, end=segment.end)
#     406 for other_segment in other.segments_list_.irange(maximum=temp):
# --> 407     if segment.intersects(other_segment):
#     408         yield segment, other_segment
#
# File ~/anaconda3/envs/der_env/lib/python3.10/site-packages/pyannote/core/segment.py:242, in Segment.intersects(self, other)
#     239     end = min(self.end, other.end)
#     240     return Segment(start=start, end=end)
# --> 242 def intersects(self, other: 'Segment') -> bool:
#     243     """Check whether two segments intersect each other
#     244
#     245     Parameters
#    (...)
#     253         True if segments intersect, False otherwise
#     254     """
#     256     return (self.start < other.start and
#     257             other.start < self.end - SEGMENT_PRECISION) or \
#     258            (self.start > other.start and
#     259             self.start < other.end - SEGMENT_PRECISION) or \
#     260            (self.start == other.start)
#
# KeyboardInterrupt:

# %% [markdown]
# ##### PRINT OUTPUTS

# %%
# Print the full results table
df = pd.DataFrame(results)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df

# %%
# df[[
#     "Model Type",
#     "Audio Type",
#     "Speaker Mode",
#     "Overlap Mode",
#     "VAD",
#     "Embedding",
#     "video_id", # Corresponds to the file id in other parts of the script
#     "DER",
#     "False Alarm %",
#     "Missed Speech %",
#     "Confusion %",
#     "Correct %"
# ]]

# %% [markdown]
# ##### GENERATE SUMMARY OF OUTPUT

# %%
summary = (
     df.groupby([
        "Audio Type",
        "Speaker Mode",
        "Overlap Mode"
    ])
    .agg({
        "DER": ["mean", "median", "std"],
        "False Alarm %": ["mean", "median", "std"],
        "Missed Speech %": ["mean", "median", "std"],
        "Confusion %": ["mean", "median", "std"],
        "Correct %": ["mean", "median", "std"]
    })
    .reset_index()
)

# For a grid structure with no merges
summary.columns = [
    "Audio Type",
    "Speaker Mode",
    "Overlap Mode",
    "DER Mean",
    "DER Median",
    "DER Std",
    "FA Mean",
    "FA Median",
    "FA Std",
    "Missed Mean",
    "Missed Median",
    "Missed Std",
    "Confusion Mean",
    "Confusion Median",
    "Confusion Std",
    "Correct Mean",
    "Correct Median",
    "Correct Std"
]

# summary = summary.sort_values(
#     ("DER", "median")
# )

summary
